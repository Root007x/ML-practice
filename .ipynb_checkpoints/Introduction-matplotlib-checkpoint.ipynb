# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
# Out:
# []

# %%
plt.plot();

# %%
plt.plot()
plt.show()

# %%
plt.plot([1,2,3,4])

# %%
x = [1,2,3,4]
y = [11,22,33,44]
plt.plot(x,y)

# %%
# 1st method 
fig = plt.figure()
ax = fig.add_subplot()
plt.show()

# %%
# 2nd method
fig = plt.figure()
ax = fig.add_axes([1,1,1,1])
ax.plot(x,y)
plt.show()

# %%
# 3rd method (recommended)
fig, ax = plt.subplots()
ax.plot(x,[50,100,200,300])
type(fig), type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._axes.Axes)

# %% [markdown]
# ## Matplolib example workflow

# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4]
y = [11,22,33,44]

# oop style
fig, ax = plt.subplots(figsize=(10,10)) # height and width
ax.plot(x,y)
ax.set(title="Simple Plot",
      xlabel="x-axis",
      ylabel="y-axis")

fig.savefig("figure/sample-plot.png")

# %% [markdown]
# ## Making figures with Numpy arrays
# * Line plot
# * Scatter Plot
# * Bar plot
# * Histogram
# * subplot

# %%
import numpy as np

# %%
x = np.linspace(0,10,100)
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
#         6.56565657,  6.66666667,  6.76767677,  6.86868687,  6.96969697,
#         7.07070707,  7.17171717,  7.27272727,  7.37373737,  7.47474747,
#         7.57575758,  7.67676768,  7.77777778,  7.87878788,  7.97979798,
#         8.08080808,  8.18181818,  8.28282828,  8.38383838,  8.48484848,
#         8.58585859,  8.68686869,  8.78787879,  8.88888889,  8.98989899,
#         9.09090909,  9.19191919,  9.29292929,  9.39393939,  9.49494949,
#         9.5959596 ,  9.6969697 ,  9.7979798 ,  9.8989899 , 10.        ])

# %%
# plot the data and create a line plot
fig, ax = plt.subplots()
ax.plot(x,x**2)

# %%
# use the same data to make scatter plot
fig, ax = plt.subplots()
ax.scatter(x, np.exp(x))

# %%
# Another scatter plot
fig, ax = plt.subplots()
ax.scatter(x,np.sin(x))

# %%
# Make a plot from dictionary
nut_butter = {
    "A butter" : 10,
    "B butter" : 20,
    "C butter" : 30
}
fig, ax = plt.subplots()
ax.bar(nut_butter.keys(),nut_butter.values()) #(x,y)
ax.set(title="Lopu shop",
      ylabel="Price")
plt.show()

# %%
fig, ax = plt.subplots()
ax.barh(list(nut_butter.keys()),list(nut_butter.values()))
# Out:
# <BarContainer object of 3 artists>

# %%
# Histogram

x = np.random.randn(1000)

# %%
fig, ax = plt.subplots()
ax.hist(x)
plt.show()

# %% [markdown]
# ## Two option for subplots

# %%
# subplot option 1
fig, ((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows=2,ncols=2,figsize=(10,5))

# plot to each different axis
ax1.plot(x,x/2)
ax2.scatter(np.random.random(10),np.random.random(10))
ax3.bar(nut_butter.keys(),nut_butter.values())
ax4.hist(x)
plt.show()

# %%
# subplots option 2
fig, ax = plt.subplots(nrows=2,ncols=2,figsize=(10,5))

# plot to each different index
ax[0,0].plot(x,x/2)
ax[0,1].scatter(np.random.random(10),np.random.random(10))
ax[1,0].bar(nut_butter.keys(),nut_butter.values())
ax[1,1].hist(x)
plt.show()

# %% [markdown]
# ## Plotting from pandas DataFrames

# %%
import pandas as pd

# %%
df = pd.read_csv("datasheet/car-sales.csv")
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
df["Price"] = df["Price"].str.replace('[\$\,\.]','',regex=True)
df
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
# Remove last tow zeros
df["Price"] = df["Price"].str[:-2]
df
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
df["Sale Date"] = pd.date_range("1/1/2020",periods=len(df))
df
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2020-01-01
# 1   Honda    Red          87899      4   5000 2020-01-02
# 2  Toyota   Blue          32549      3   7000 2020-01-03
# 3     BMW  Black          11179      5  22000 2020-01-04
# 4  Nissan  White         213095      4   3500 2020-01-05
# 5  Toyota  Green          99213      4   4500 2020-01-06
# 6   Honda   Blue          45698      4   7500 2020-01-07
# 7   Honda   Blue          54738      4   7000 2020-01-08
# 8  Toyota  White          60000      4   6250 2020-01-09
# 9  Nissan  White          31600      4   9700 2020-01-10

# %%
df["Total Sales"] = df["Price"].astype(int).cumsum() # cumalative sum
df
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
df.plot(x="Sale Date",y="Total Sales")
# Out:
# <Axes: xlabel='Sale Date'>

# %%
df['Price'] = df['Price'].astype(int)
df.plot(x="Odometer (KM)",y="Price",kind="scatter")
# Out:
# <Axes: xlabel='Odometer (KM)', ylabel='Price'>

# %%
# Bar graph

x = np.random.rand(10,4)

# Turn it into a dataframe

df = pd.DataFrame(x,columns=['a','b','c','d'])
df.plot.bar()
# Out:
# <Axes: >

# %%
df.plot(kind='bar')
# Out:
# <Axes: >

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
df.plot(x="Make",y="Odometer (KM)",kind="bar")
# Out:
# <Axes: xlabel='Make'>

# %%
# Histogram

df['Odometer (KM)'].plot.hist();

# %%
df['Odometer (KM)'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Odometer (KM)'].plot.hist(bins=10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Let's try on another dataset
heart_disease = pd.read_csv("datasheet/92 - heart-disease.csv")
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease['age'].plot.hist(bins=10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease.plot.hist(figsize=(10,30),subplots=True)
# Out:
# array([<Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>],
#       dtype=object)

# %% [markdown]
# ## Which one should I use? (pyplot vs matplotlib OO method)?
# * When plotting something quickly, okey to use pyplot method
# * When plotting something more advanced, use oo method

# %%
over_50 = heart_disease[ heart_disease['age'] > 50]
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# Pyplot method 
over_50.plot(kind="scatter",
            x='age',
            y='chol',
            c='target')
# Out:
# <Axes: xlabel='age', ylabel='chol'>

# %%
# oo method mixed with pyplot
fig, ax = plt.subplots(figsize=(10,6))
over_50.plot(kind='scatter',
       x='age',
       y='chol',
       c='target',
            ax= ax)
ax.set_xlim([45,100]) # x axis limit from 45 to 100
# Out:
# (45.0, 100.0)

# %%
## OO method from scratch
fig, ax = plt.subplots(figsize=(10,6))

# plot the data
scatter = ax.scatter(x=over_50.age,y=over_50.chol,c=over_50.target)
ax.set(title="Heart Disease and Cholesterol Levels",xlabel='Age',ylabel="Cholesterol")
ax.legend(*scatter.legend_elements(),title="Target")

# Horrizantal line
ax.axhline(over_50['chol'].mean(),linestyle="--")
plt.show()

# %%
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# subplot of chol, age, thalach
fig, (ax0,ax1) = plt.subplots(nrows=2,
                             ncols=1,figsize=(10,10))

# Add data to ax0
scatter = ax0.scatter(x=over_50.age,y=over_50.chol,c=over_50.target)

# Customize ax0
ax0.set(title="Heart Disease and cholestrol Levels",xlabel='Age',ylabel="Cholestrol")
# Add a legend to ax0
ax0.legend(*scatter.legend_elements(),title="Target")
# Add meanline
ax0.axhline(y=over_50.chol.mean(),
           linestyle="--")


scatter1 = ax1.scatter(x=over_50.age,y=over_50.thalach,c=over_50.target)
ax1.set(title="Heart Disease and Thalach Levels",xlabel="Age",ylabel="Thalach")
ax1.legend(*scatter1.legend_elements(),title='Target')
ax1.axhline(y=over_50.thalach.mean(),linestyle="--")

# Add a title to figure
fig.suptitle("Heart Disease Analysis",fontsize=16,fontweight="bold")

plt.show()

# %% [markdown]
# ## Customizing Matplotlib plots and getting stylish

# %%
# See the different styles avilable
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
df['Odometer (KM)'].plot()
# Out:
# <Axes: >

# %%
plt.style.use("seaborn-v0_8-whitegrid")

# %%
df['Odometer (KM)'].plot()
# Out:
# <Axes: >

# %%
plt.style.use("seaborn-v0_8")

# %%
df['Odometer (KM)'].plot()
# Out:
# <Axes: >

# %%
# Create some data
x = np.random.randn(10,4)
x
# Out:
# array([[-1.69821524,  0.85390475,  0.40094484, -0.01019685],
#        [-0.99623449,  0.70987544,  1.32385065, -1.05240951],
#        [-2.34515808,  1.33744961,  0.55223593,  0.69367604],
#        [-0.11410647, -0.75987408,  0.28203477, -1.41632943],
#        [ 0.14780376, -1.03545434,  0.60808339,  0.62169156],
#        [ 0.30914203,  0.52016717,  0.65162571, -1.494652  ],
#        [-0.21458524, -0.21058626,  0.31280148, -0.07619245],
#        [ 1.1319349 ,  0.71460375,  1.01750029, -0.2645528 ],
#        [-0.62277843,  2.03699913,  0.04613208,  0.90250614],
#        [-1.31558913,  1.31036759, -0.2274779 , -0.28928287]])

# %%
df = pd.DataFrame(x,columns=['a','b','c','d'])

# %%
df
# Out:
#           a         b         c         d
# 0 -1.698215  0.853905  0.400945 -0.010197
# 1 -0.996234  0.709875  1.323851 -1.052410
# 2 -2.345158  1.337450  0.552236  0.693676
# 3 -0.114106 -0.759874  0.282035 -1.416329
# 4  0.147804 -1.035454  0.608083  0.621692
# 5  0.309142  0.520167  0.651626 -1.494652
# 6 -0.214585 -0.210586  0.312801 -0.076192
# 7  1.131935  0.714604  1.017500 -0.264553
# 8 -0.622778  2.036999  0.046132  0.902506
# 9 -1.315589  1.310368 -0.227478 -0.289283

# %%
ax = df.plot(kind='bar')

# %%
# Customize our plot with the set method

ax = df.plot(kind='bar')
ax.set(title='Random Number Bar Graph',xlabel='Row Number',ylabel="Random Number")
ax.legend().set_visible(True)

# %%
plt.style.use("seaborn-v0_8-whitegrid")

## OO method from scratch
fig, ax = plt.subplots(figsize=(10,6))

# plot the data
scatter = ax.scatter(x=over_50.age,y=over_50.chol,c=over_50.target,cmap="summer")
ax.set(title="Heart Disease and Cholesterol Levels",xlabel='Age',ylabel="Cholesterol")
ax.legend(*scatter.legend_elements(),title="Target")

# Horrizantal line
ax.axhline(over_50['chol'].mean(),linestyle="--")
plt.show()

# %%
# subplot of chol, age, thalach
fig, (ax0,ax1) = plt.subplots(nrows=2,
                             ncols=1,figsize=(10,10))

# Add data to ax0
scatter = ax0.scatter(x=over_50.age,y=over_50.chol,c=over_50.target,cmap="winter")

# Customize ax0
ax0.set(title="Heart Disease and cholestrol Levels",xlabel='Age',ylabel="Cholestrol")
# Change the x axis limits
ax0.set_xlim([50,80])
# Add a legend to ax0
ax0.legend(*scatter.legend_elements(),title="Target")
# Add meanline
ax0.axhline(y=over_50.chol.mean(),
           linestyle="--")


scatter1 = ax1.scatter(x=over_50.age,y=over_50.thalach,c=over_50.target,cmap='winter')
ax1.set(title="Heart Disease and Thalach Levels",xlabel="Age",ylabel="Thalach")
ax1.set_xlim([50,80])
ax1.set_ylim([50,200])
ax1.legend(*scatter1.legend_elements(),title='Target')
ax1.axhline(y=over_50.thalach.mean(),linestyle="--")

# Add a title to figure
fig.suptitle("Heart Disease Analysis",fontsize=16,fontweight="bold")

plt.show()

# %%
fig.savefig('figure/heart_analysis.png')
